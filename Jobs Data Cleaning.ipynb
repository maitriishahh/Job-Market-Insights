# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('job_desc.xlsx')
df_copy = df
df.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089840000000000  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454000000000  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640000000000  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688193000000000  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117058000000000  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Job Id            1048575 non-null  int64
#  1   Experience        1048575 non-null  object
#  2   Qualifications    1048575 non-null  object
#  3   Salary Range      1048575 non-null  object
#  4   location          1048575 non-null  object
#  5   Country           1048575 non-null  object
#  6   latitude          1048575 non-null  float64
#  7   longitude         1048575 non-null  float64
#  8   Work Type         1048575 non-null  object
#  9   Company Size      1048575 non-null  int64
#  10  Job Posting Date  1048575 non-null  datetime64[ns]
#  11  Preference        1048575 non-null  object
#  12  Contact Person    1048575 non-null  object
#  13  Contact           1048575 non-null  object
#  14  Job Title         1048575 non-null  object
# ...

# %%
df.shape
# Out:
# (1048575, 23)

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Length: 1048575, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Job_Id            1048575 non-null  int64
#  1   Experience        1048575 non-null  object
#  2   Qualifications    1048575 non-null  object
#  3   Salary_Range      1048575 non-null  object
#  4   Location          1048575 non-null  object
#  5   Country           1048575 non-null  object
#  6   latitude          1048575 non-null  float64
#  7   longitude         1048575 non-null  float64
#  8   Work_Type         1048575 non-null  object
#  9   Company Size      1048575 non-null  int64
#  10  Job Posting Date  1048575 non-null  datetime64[ns]
#  11  Preference        1048575 non-null  object
#  12  Contact Person    1048575 non-null  object
#  13  Contact           1048575 non-null  object
#  14  Job_Title         1048575 non-null  object
# ...

# %%
df = df.rename(columns={'Job Id':'Job_Id','Salary Range':'Salary_Range','location':'Location','Work Type':'Work_Type','Job Title':'Job_Title','Job Portal':'Job_Portal','skills':'Skills','Company Profile':'Company_Profile'})

# %%
df = df.drop(columns=['latitude','longitude','Company Size','Job Posting Date','Contact Person','Contact','Job Description','Benefits','Responsibilities'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 14 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Job_Id           1048575 non-null  int64
#  1   Experience       1048575 non-null  object
#  2   Qualifications   1048575 non-null  object
#  3   Salary_Range     1048575 non-null  object
#  4   Location         1048575 non-null  object
#  5   Country          1048575 non-null  object
#  6   Work_Type        1048575 non-null  object
#  7   Preference       1048575 non-null  object
#  8   Job_Title        1048575 non-null  object
#  9   Role             1048575 non-null  object
#  10  Job_Portal       1048575 non-null  object
#  11  Skills           1048575 non-null  object
#  12  Company          1048575 non-null  object
#  13  Company_Profile  1044968 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 112.0+ MB

# %%
df.head(3)
# Out:
#              Job_Id     Experience Qualifications Salary_Range  Location  \
# 0  1089840000000000  5 to 15 Years         M.Tech    $59K-$99K   Douglas
# 1   398454000000000  2 to 12 Years            BCA   $56K-$116K  Ashgabat
# 2   481640000000000  0 to 12 Years            PhD   $61K-$104K     Macao
#
#             Country  Work_Type Preference                     Job_Title  \
# 0       Isle of Man     Intern     Female  Digital Marketing Specialist
# 1      Turkmenistan     Intern     Female                 Web Developer
# 2  Macao SAR, China  Temporary       Male            Operations Manager
#
#                       Role    Job_Portal  \
# 0     Social Media Manager      Snagajob
# 1   Frontend Web Developer      Idealist
# 2  Quality Control Manager  Jobs2Careers
#
#                                               Skills  \
# 0  Social media platforms (e.g., Facebook, Twitte...
# 1  HTML, CSS, JavaScript Frontend frameworks (e.g...
# ...

# %%
df["Job_Id"] = df["Job_Id"].astype(str).str[:8]

# %%
import ast

# Safely extract sector/industry
def extract_value(x, key):
    try:
        if isinstance(x, str):   # only parse if it's a string
            return ast.literal_eval(x).get(key)
    except:
        return None
    return None

df["Sector"] = df["Company_Profile"].apply(lambda x: extract_value(x, "Sector"))
df["Industry"] = df["Company_Profile"].apply(lambda x: extract_value(x, "Industry"))

# %%
df['Experience'] = df['Experience'].str.replace("to","-",regex=False)

# %%
df = df.drop(columns=['Company_Profile'])

# %%
df
# Out:
#            Job_Id    Experience Qualifications Salary_Range     Location  \
# 0        10898400  5 - 15 Years         M.Tech    $59K-$99K      Douglas
# 1        39845400  2 - 12 Years            BCA   $56K-$116K     Ashgabat
# 2        48164000  0 - 12 Years            PhD   $61K-$104K        Macao
# 3        68819300  4 - 11 Years            PhD    $65K-$91K   Porto-Novo
# 4        11705800  1 - 12 Years            MBA    $64K-$87K     Santiago
# ...           ...           ...            ...          ...          ...
# 1048570  16255600   2 - 9 Years          B.Com   $64K-$127K        Kabul
# 1048571  17753200  1 - 14 Years            MCA   $56K-$125K     Kingston
# 1048572  65242300   3 - 9 Years            BBA   $59K-$123K       Muscat
# 1048573  14284600  3 - 10 Years            MCA   $62K-$119K  Mexico City
# 1048574  58731600   1 - 9 Years          M.Com   $61K-$109K     Sarajevo
#
#                         Country  Work_Type Preference  \
# ...

# %%
# !pip install ftfy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The script ftfy.exe is installed in 'C:\Users\hp\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import ftfy
df["Location"] = df["Location"].apply(ftfy.fix_text)

# %%
df['Location']
# Out:
# 0              Douglas
# 1             Ashgabat
# 2                Macao
# 3           Porto-Novo
# 4             Santiago
#               ...
# 1048570          Kabul
# 1048571       Kingston
# 1048572         Muscat
# 1048573    Mexico City
# 1048574       Sarajevo
# Name: Location, Length: 1048575, dtype: object

# %%
df['Skills'] = df['Skills'].str.replace("and","",regex=False)

# %%
df
# Out:
#            Job_Id    Experience Qualifications Salary_Range     Location  \
# 0        10898400  5 - 15 Years         M.Tech    $59K-$99K      Douglas
# 1        39845400  2 - 12 Years            BCA   $56K-$116K     Ashgabat
# 2        48164000  0 - 12 Years            PhD   $61K-$104K        Macao
# 3        68819300  4 - 11 Years            PhD    $65K-$91K   Porto-Novo
# 4        11705800  1 - 12 Years            MBA    $64K-$87K     Santiago
# ...           ...           ...            ...          ...          ...
# 1048570  16255600   2 - 9 Years          B.Com   $64K-$127K        Kabul
# 1048571  17753200  1 - 14 Years            MCA   $56K-$125K     Kingston
# 1048572  65242300   3 - 9 Years            BBA   $59K-$123K       Muscat
# 1048573  14284600  3 - 10 Years            MCA   $62K-$119K  Mexico City
# 1048574  58731600   1 - 9 Years          M.Com   $61K-$109K     Sarajevo
#
#                         Country  Work_Type Preference  \
# ...

# %%
df.to_excel("job_desc_new.xlsx", index=False, engine='openpyxl')

# %%
import pandas as pd
df1 = pd.read_excel('job_desc_new.xlsx')
df1['Skills'].head()
# Out:
# 0    Social media platforms (e.g., Facebook, Twitte...
# 1    HTML, CSS, JavaScript Frontend frameworks (e.g...
# 2    Quality control processes  methodologies Stati...
# 3    Wireless network design  architecture Wi-Fi st...
# 4    Event planning Conference logistics Budget man...
# Name: Skills, dtype: object

# %%
import re

# Assume your DataFrame is loaded and stored in a variable named 'df'.
# For demonstration purposes, a sample DataFrame is created below.
# You will replace this part with your actual code to load your data (e.g., from a CSV file).

# Create an empty list to store the cleaned skills.
cleaned_skills_list = []

# Iterate over each skill string in the original 'Skills' column.
for skill_string in df1['Skills']:
    # Step 1: Remove parenthetical notes.
    cleaned_string = re.sub(r'\s*\(.*?\)', '', skill_string)

    # Step 2: Normalize multiple spaces to a single space.
    cleaned_string = re.sub(r'\s+', ' ', cleaned_string)

    # Step 3: Insert a comma before each capitalized word to create a consistent delimiter.
    # The regex `\s([A-Z])` finds a space followed by an uppercase letter.
    cleaned_string = re.sub(r'\s([A-Z])', r', \1', cleaned_string)

    # Step 4: Split the string by the comma delimiter and clean up each skill.
    individual_skills = [skill.strip() for skill in cleaned_string.split(',')]

    # Step 5: Filter out any empty strings that may have resulted from the split.
    final_skills = [skill for skill in individual_skills if skill]

    # Add the list of cleaned skills to our list.
    cleaned_skills_list.append(final_skills)

# Add the new list of cleaned skills to the DataFrame as a new column.
df1['Cleaned_Skills'] = cleaned_skills_list

# Display the DataFrame with both original and cleaned skills columns.
print(df1[['Skills', 'Cleaned_Skills']])
# Out:
#                                                    Skills  \
# 0       Social media platforms (e.g., Facebook, Twitte...
# 1       HTML, CSS, JavaScript Frontend frameworks (e.g...
# 2       Quality control processes  methodologies Stati...
# 3       Wireless network design  architecture Wi-Fi st...
# 4       Event planning Conference logistics Budget man...
# ...                                                   ...
# 421286  Supplier diversity programs Diversity  inclusi...
# 421287  Nursing leadership Charge nurse responsibiliti...
# 421288  UI design principles  best practices Graphic d...
# 421289  Project management Communication Time manageme...
# 421290  Data analysis tools (e.g., SQL, Python) Data v...
#
#                                            Cleaned_Skills
# 0       [Social media platforms, Content creation sche...
# 1       [HTML, CSS, JavaScript, Frontend frameworks, U...
# 2       [Quality control processes methodologies, Stat...
# ...

# %%
df1.drop(columns='Skills')
# Out:
#           Job_Id  Avg_Experience Qualifications  Min_Salary  Max_Salary  \
# 0       10898400              10         M.Tech       59000       99000
# 1       39845400               7            BCA       56000      116000
# 2       48164000               6            PhD       61000      104000
# 3       68819300               8            PhD       65000       91000
# 4       11705800               6            MBA       64000       87000
# ...          ...             ...            ...         ...         ...
# 421286  89902000               8            MBA       56000       93000
# 421287  59248100               8            PhD       62000      115000
# 421288  82886800               8          M.Com       63000      101000
# 421289  65242300               6            BBA       59000      123000
# 421290  58731600               5          M.Com       61000      109000
#
#              Location                 Country  Work_Type Preference  \
# ...

# %%
import pandas as pd

sorted_role_mapping = {
    'Accessibility Developer':'Accessibility Developer',
    'Account Executive': 'Account Executive',
    'Account Manager': 'Account Manager',
    'Accounting Manager': 'Accounting Manager',
    'Account Strategist': 'Account Strategist',
    'Accountant': 'Accountant',
    'Accounting Controller':'Accounting Controller',
    'Account Executive':'Account Executive',
    'Accounts Payable Specialist': 'Accounts Payable Specialist',
    'Accounts Receivable Specialist': 'Accounts Receivable Specialist',
    'Acute Care Nurse Practitioner':'Nurse Practitioner',
    'Addiction Counselor': 'Addiction Counselor',
    'Administrative Assistant': 'Administrative Assistant',
    'Administrative Coordinator': 'Administrative Coordinator',
    'Administrative Manager': 'Administrative Manager',
    'Administrative Officer': 'Administrative Officer',
    'Adult Speech Therapist': 'Speech Therapist',
    'Advertising Account Executive': 'Account Executive',
    'Agile Product Owner': 'Product Manager/Owner',
    'Agile Project Manager': 'Project Manager',
    'Aircraft Design Engineer': 'Aerospace Engineer',
    'Analytical Chemist': 'Chemist',
    'API Developer': 'Software Developer',
    'Architectural Designer': 'Architectural Designer',
    'Architectural Drafter': 'Architectural Drafter',
    'Art Curator': 'Art Curator',
    'Art Education Coordinator': 'Art Education Coordinator',
    'Art Director': 'Art Director',
    'Assistant Manager': 'Assistant Manager',
    'Attorney': 'Lawyer',
    'Auditor': 'Auditor',
    'Automation Test Engineer': 'Automation Tester',
    'Automation Tester': 'Automation Tester',
    'Avionics Engineer': 'Aerospace Engineer',
    'Backend Developer': 'Software Developer',
    'Backend Web Developer': 'Software Developer',
    'B2B Sales Consultant': 'Sales Consultant',
    'Benefits Coordinator': 'Benefits Coordinator',
    'Big Data Engineer': 'Data Engineer',
    'Biostatistician': 'Biostatistician',
    'Bookkeeper': 'Bookkeeper',
    'Brand Director': 'Director',
    'Brand Manager': 'Brand Manager',
    'Brand Promoter':'Brand Promoter',
    'Brand Marketing Analyst': 'Marketing Analyst',
    'Brand PR Specialist': 'PR Specialist',
    'Brand Strategist': 'Brand Strategist',
    'Bridge Engineer':'Bridge Engineer',
    'Budget Analyst': 'Budget Analyst',
    'Business Analyst': 'Business Analyst',
    'Business Development Director': 'Director',
    'Business Development Manager': 'Business Development Manager',
    'Business Intelligence Analyst': 'Business Intelligence Analyst',
    'Business Systems Analyst': 'Business Systems Analyst',
    'Business Tax Consultant':'Business Tax Consultant',
    'CAD Technician': 'CAD Technician',
    'Call Center Agent': 'Call Center Agent',
    'Charge Nurse': 'Charge Nurse',
    'Chemical Engineer': 'Chemical Engineer',
    'Child Custody Lawyer': 'Lawyer',
    'Child Psychologist': 'Psychologist',
    'Child Welfare Worker': 'Child Welfare Worker',
    'City Planner': 'City Planner',
    'Civil Engineer': 'Civil Engineer',
    'Classroom Teacher': 'Teacher',
    'Client Relationship Manager': 'Client Relationship Manager',
    'Client Service Representative': 'Client Service Representative',
    'Client Services Coordinator': 'Client Services Coordinator',
    'Clinical Manager': 'Clinical Manager',
    'Clinical Nurse': 'Clinical Nurse',
    'Clinical Nurse Manager': 'Clinical Manager',
    'Clinical Nurse Specialist': 'Clinical Nurse Specialist',
    'Clinical Psychologist': 'Psychologist',
    'Cloud Architect': 'Cloud Architect',
    'Cloud Systems Engineer': 'Cloud Engineer',
    'Commercial Interior Designer': 'Interior Designer',
    'Commercial Landscape Architect': 'Landscape Architect',
    'Commercial Manager': 'Commercial Manager',
    'Community Manager': 'Community Manager',
    'Competitive Intelligence Analyst':'Competitive Intelligence Analyst',
    'Compliance regulatory knowledge': 'Compliance Analyst',
    'Conference Manager': 'Conference Manager',
    'Construction Engineer': 'Construction Engineer',
    'Construction Project Coordinator': 'Project Coordinator',
    'Construction Project Manager': 'Project Manager',
    'Controls Engineer':'Controls Engineer',
    'Content Marketing Manager': 'Marketing Manager',
    'Content Marketing Specialist': 'Marketing Specialist',
    'Content Strategist': 'Content Strategist',
    'Content Creator':'Content Creator',
    'Content SEO Strategist':'Content SEO Strategist',
    'Corporate Litigator':'Corporate Litigator',
    'Content Writer': 'Writer',
    'Copywriter': 'Writer',
    'Corporate Trainer': 'Corporate Trainer',
    'Corporate Attorney':'Lawyer',
    'Corporate Event Coordinator':'Corporate Event Coordinator',
    'Corporate Paralegal':'Corporate Paralegal',
    'Corporate Counsel':'Corporate Counsel',
    'Corporate Event Planner':'Corporate Event Planner',
    'Counselor': 'Counselor',
    'Court Clerk':'Clerk',
    'Creative Director': 'Creative Director',
    'Creative Copywriter':'Creative Copywriter',
    'Credit Analyst': 'Credit Analyst',
    'Crisis Communication Manager':'Crisis Communication Manager',
    'Customer Relationship Manager': 'Customer Relationship Manager',
    'Customer Service Manager': 'Customer Service Manager',
    'Customer Success Manager':'Customer Success Manager',
    'Customer Experience Strategist':'Customer Experience Strategist',
    'Customer Support Specialist':'Customer Support Specialist',
    'Customer Service Representative': 'Customer Service Representative',
    'Customer Support Manager': 'Customer Support Manager',
    'Cyber Security Analyst': 'Cyber Security Analyst',
    'Cybersecurity Analyst': 'Cyber Security Analyst',
    'Data Entry Specialist':'Data Entry Specialist',
    'Data Analyst': 'Data Analyst',
    'Data Analyst Researcher':'Data Analyst',
    'Data Engineer': 'Data Engineer',
    'Data Scientist': 'Data Scientist',
    'Data Quality Analyst':'Data Quality Analyst',
    'Data Architect':'Data Architect',
    'Data Business Analyst':'Data Business Analyst',
    'Database Administrator': 'Database Administrator',
    'Database Analyst': 'Database Analyst',
    'Database Security Specialist':'Database Security Specialist',
    'Database Developer':'Database Developer',
    'Dental Assistant': 'Dental Assistant',
    'Dental Hygienist': 'Dental Hygienist',
    'Dental Hygiene Educator':'Dental Hygienist',
    'Dental Public Health Hygienist':'Dental Hygienist',
    'Dentist': 'Dentist',
    'DevOps Engineer':'DevOps Engineer',
    'Demand Planner':'Demand Planner',
    'Desktop Support Technician':'Support Technician',
    'Design Engineer':'Design Engineer',
    'Deliverability Analyst':'Deliverability Analyst',
    'Dietitian': 'Dietitian',
    'Digital Marketing Director':'Marketing Director',
    'Digital Marketing Analyst':'Marketing Analyst',
    'Digital Marketing Manager': 'Marketing Manager',
    'Digital Marketing Specialist': 'Marketing Specialist',
    'Digital Marketing Coordinator':'Marketing Coordinator',
    'Digital Strategist': 'Digital Strategist',
    'Director of Marketing': 'Marketing Director',
    'Director of Sales': 'Sales Director',
    'Documentation Specialist':'Documentation Specialist',
    'Economist': 'Economist',
    'E-commerce Web Designer':'E-commerce Web Designer',
    'Editor': 'Editor',
    'Electrical Engineer': 'Electrical Engineer',
    'Electronics Hardware Engineer':'Electronics Engineer',
    'Email Marketing Specialist': 'Marketing Specialist',
    'Environmental Impact Analyst':'Environmental Impact Analyst',
    'Email Campaign Manager':'Campaign Manager',
    'Environmental Designer':'Environmental Designer',
    'Employee Development Manager':'Employee Development Manager',
    'Employment Lawyer':'Lawyer',
    'Emergency Medicine Physician Assistant':'Physician Assistant',
    'Employee Relations Specialist':'Relations Specialist',
    'Epidemiologist': 'Epidemiologist',
    'Event Coordinator': 'Event Coordinator',
    'Event Manager': 'Event Manager',
    'Event Planner': 'Event Planner',
    'Equine Veterinarian':'Veterinarian',
    'Exotic Animal Veterinarian':'Veterinarian',
    'Executive Assistant': 'Executive Assistant',
    'ETL Developer':'ETL Developer',
    'Enterprise Architect':'Enterprise Architect',
    'Environmental Compliance Officer':'Environmental Compliance Officer',
    'Environmental Consultant':'Environmental Consultant',
    'Environmental Planner':'Environmental Planner',
    'Event Marketing Coordinator':'Event Marketing Coordinator',
    'Facilities Manager': 'Facilities Manager',
    'Family Law Attorney':'Lawyer',
    'Family Counselor':'Counselor',
    'Family Nurse Practitioner':'Nurse Practitioner',
    'Finance Manager': 'Finance Manager',
    'Financial Advisor': 'Financial Advisor',
    'Financial Analyst': 'Financial Analyst',
    'Financial Planning Manager':'Finance Manager',
    'Financial Accountant':'Accountant',
    'Financial Planner': 'Financial Planner',
    'Firefighter': 'Firefighter',
    'Fine Arts Instructor':'Fine Arts Instructor',
    'Flight Attendant': 'Flight Attendant',
    'Food Scientist': 'Food Scientist',
    'Forensic Scientist': 'Forensic Scientist',
    'Forensic Accountant':'Forensic Accountant',
    'Front-end Developer': 'Software Developer',
    'Front-End Developer': 'Software Developer',
    'Front-end Engineer': 'Software Developer',
    'Frontend Developer': 'Software Developer',
    'Frontend Engineer': 'Software Developer',
    'Frontend Web Developer': 'Software Developer',
    'Frontend Web Designer': 'Software Developer',
    'Full Stack Developer': 'Software Developer',
    'Fullstack Developer': 'Software Developer',
    'Fundraising Manager': 'Fundraising Manager',
    'General Manager': 'General Manager',
    'Geologist': 'Geologist',
    'Geriatric Nurse Practitioner':'Nurse Practitioner',
    'Geriatric Physical Therapist':'Physical Therapist',
    'Geriatric Occupational Therapist':'Occupational Therapist',
    'Graphic Designer': 'Graphic Designer',
    'General Pediatrician':'General Pediatrician',
    'Hardware Engineer': 'Hardware Engineer',
    'Health and Safety Officer': 'Health and Safety Officer',
    'Help Desk Technician': 'Help Desk Technician',
    'Help Desk Analyst':'Help Desk Analyst',
    'Healthcare Business Analyst':'Business Analyst',
    'Help Desk Support Specialist':'Help Desk Support Specialist',
    'Hospitality Interior Designer':'Interior Designer',
    'Human Resources Assistant': 'HR Assistant',
    'Human Resources Manager': 'HR Manager',
    'Human Resources Director': 'HR Director',
    'HVAC Technician': 'HVAC Technician',
    'HVAC Engineer': 'HVAC Engineer',
    'HVAC Systems Designer':'HVAC Systems Designer',
    'HR Coordinator': 'HR Coordinator',
    'HR Generalist': 'HR Generalist',
    'HR Manager': 'HR Manager',
    'HR Compliance Specialist':'HR Compliance Specialist',
    'Industrial Designer': 'Industrial Designer',
    'Information Architect': 'Information Architect',
    'Information Technology Manager': 'IT Manager',
    'IT Manager': 'IT Manager',
    'IT Technician': 'IT Technician',
    'IT Director':'IT Director',
    'IT Support Specialist':'IT Support Specialist',
    'IT Analyst':'IT Analyst',
    'IT Systems Administrator':'IT Systems Administrator',
    'IT Project Manager':'Project Manager',
    'IT Business Analyst':'Business Analyst',
    'Interior Designer':'Interior Designer',
    'Intellectual Property Lawyer':'Lawyer',
    'In-House Counsel':'In-House Counsel',
    'Infrastructure Manager':'Infrastructure Manager',
    'Investment Analyst': 'Investment Analyst',
    'Investment Advisor': 'Investment Advisor',
    'Investment Portfolio Manager':'Investment Portfolio Manager',
    'Interaction Designer':'UX/UI Professional',
    'International Tax Consultant':'Tax Consultant',
    'Industrial Engineer':'Industrial Engineer',
    'Inside Sales Representative':'Sales Representative',
    'Inventory Manager':'Inventory Manager',
    'Inventory Control Specialist':'Inventory Manager',
    'Journalist': 'Journalist',
    'JavaScript Developer':'JavaScript Developer',
    'Java Backend Developer':'Java Developer',
    'Java Web Application Developer':'Java Developer',
    'Java Software Engineer':'Java Developer',
    'Key Account Executive':'Account Executive',
    'Key Account Manager':'Key Account Manager',
    'Lawyer': 'Lawyer',
    'Legal Secratary':'Administrative Assistant',
    'Legal Assistant':'Administrative Assistant',
    'Legal Counsel':'Legal Counsel',
    'Librarian': 'Librarian',
    'Litigation Paralegal':'Paralegal',
    'Litigation Support Specialist':'Support Specialist',
    'Live Chat Support Agent':'Live Chat Support Agent',
    'Lighting Designer':'Lighting Designer',
    'Licensed Practical Nurse': 'Licensed Practical Nurse',
    'Loan Officer': 'Loan Officer',
    'Logistician': 'Logistician',
    'Logistics Analyst':'Logistics Analyst',
    'Logistics Manager':'Logistics Manager',
    'Machinist': 'Machinist',
    'Machine Learning Engineer': 'Machine Learning Engineer',
    'Market Research Analyst': 'Market Research Analyst',
    'Market Researcher':'Market Researcher',
    'Market Research Coordinator':'Market Research Coordinator',
    'Marketing Analyst': 'Marketing Analyst',
    'Marketing Manager': 'Marketing Manager',
    'Marketing Specialist': 'Marketing Specialist',
    'Marketing Analytics Specialist':'Marketing Specialist',
    'Marketing Automation Specialist':'Marketing Specialist',
    'Market Expansion Manager':'Market Expansion Manager',
    'Manufacturing Engineer':'Manufacturing Engineer',
    'Marketing Communications Director':'Marketing Communications Director',
    'Medical Assistant': 'Medical Assistant',
    'Media Relations Specialist':'Media Relations Specialist',
    'Mediator':'Mediator',
    'Medical Technologist': 'Medical Technologist',
    'Mechanical Engineer': 'Mechanical Engineer',
    'Medical Sales Specialist':'Medical Sales Specialist',
    'Mechanical Design Engineer': 'Mechanical Engineer',
    'Mental Health Counselor':'Mental Health Counselor',
    'Mental Health Occupational Therapist':'Occupational Therapist',
    'Mobile App Developer':'App Developer',
    'Mergers and Acquisitions Advisor':'Mergers and Acquisitions Advisor',
    'Network Engineer': 'Network Engineer',
    'Network Administrator':'Network Administrator',
    'Network Security Engineer': 'Network Engineer',
    'Network Security Analyst': 'Network Security Analyst',
    'Network Security Specialist': 'Network Security Specialist',
    'Network Support Specialist':'Network Support Specialist',
    'Network Performance Analyst':'Network Performance Analyst',
    'NoSQL Database Engineer':'Data Engineer',
    'Nurse Practitioner': 'Nurse Practitioner',
    'Nursing Director':'Nursing Director',
    'Nurse Educator':'Nurse Educator',
    'Occupational Therapist': 'Occupational Therapist',
    'Office Administrator': 'Office Administrator',
    'Office Coordinator':'Office Coordinator',
    'Office Assistant': 'Office Assistant',
    'Office Manager': 'Office Manager',
    'Onboarding Specialist':'Onboarding Specialist',
    'Orthopedic Physical Therapist':'Orthopedic Physical Therapist',
    'Outside Sales Representative':'Sales Representative',
    'Operations Manager': 'Operations Manager',
    'Operations Director':'Director',
    'Paid Advertising Specialist':'Paid Advertising Specialist',
    'Paralegal': 'Paralegal',
    'Payroll Specialist': 'Payroll Specialist',
    'PPC Specialist': 'PPC Specialist',
    'PCB Designer':'PCB Designer',
    'Personal Assistant':'Personal Assistant',
    'Personal Secretary':'Personal Secretary',
    'Pediatric Speech Therapist':'Speech Therapist',
    'Pediatric Nurse Practitioner':'Nurse Practitioner',
    'Pediatric Physical Therapist':'Physical Therapist',
    'Periodontal Therapist':'Periodontal Therapist',
    'Pediatric Surgeon':'Pediatric Surgeon',
    'Pediatric Specialist':'Pediatric Specialist',
    'Pediatric Occupational Therapist':'Occupational Therapist',
    'Performance Testing Specialist': 'Quality Assurance/Control',
    'Performance Tester':'Quality Assurance/Control',
    'Personal Tax Consultant':'Tax Consultant',
    'Pharmacist': 'Pharmacist',
    'Photographer': 'Photographer',
    'Physical Therapist': 'Physical Therapist',
    'Physician Assistant': 'Physician Assistant',
    'Plumber': 'Plumber',
    'Police Officer': 'Police Officer',
    'Power BI Analyst': 'Data Analyst',
    'Power Systems Engineer':'Power Systems Engineer',
    'Portfolio Manager':'Portfolio Manager',
    'Procurement Manager': 'Procurement Manager',
    'Procurement Analyst': 'Procurement Analyst',
    'Product Manager': 'Product Manager/Owner',
    'Product Marketing Manager':'Product Manager',
    'Procurement Coordinator':'Procurement Coordinator',
    'Procurement Specialist':'Procurement Specialist',
    'Product Brand Manager':'Product Manager',
    'Product Demonstrator':'Product Demonstrator',
    'Product Designer':'Product Designer',
    'Project Architect':'Project Architect',
    'Project Manager': 'Project Manager',
    'Project Coordinator':'Project Coordinator',
    'Primary Care Nurse Practitioner':'Nurse Practitioner',
    'Primary Care Physician Assistant':'Physician Assistant',
    'Primary Care Provider':'Nurse',
    'Print Graphic Designer':'Graphic Designer',
    'Psychiatrist': 'Psychiatrist',
    'Process Engineer':'Process Engineer',
    'Psychologist': 'Psychologist',
    'Public Health Nurse': 'Public Health Nurse',
    'Public Health Specialist': 'Public Health Specialist',
    'Public Relations Manager': 'Public Relations Manager',
    'Public Relations Specialist': 'PR Specialist',
    'Purchasing Coordinator':'Purchasing Coordinator',
    'QA Tester':'QA Tester',
    'QA Manager':'Quality Manager',
    'Quality Assurance Analyst': 'Quality Analyst',
    'Quality Assurance Manager': 'Quality Manager',
    'Quality Control Manager': 'Quality Manager',
    'Quality Control Engineer': 'Quality Engineer',
    'Quality Control Analyst': 'Quality Analyst',
    'Radiologic Technologist': 'Radiologic Technologist',
    'Real Estate Agent': 'Real Estate Agent',
    'Real Estate Paralegal':'Real Estate Paralegal',
    'Record Keeper':'Record Keeper',
    'Receptionist': 'Receptionist',
    'Recovery Coach':'Recovery Coach',
    'Research Analyst':'Research Analyst',
    'Recruitment Manager': 'Recruitment Manager',
    'Recruitment Coordinator': 'Recruitment Manager',
    'Regional Sales Manager': 'Sales Manager',
    'Regional Sales Director':'Sales Director',
    'Registered Nurse': 'Registered Nurse',
    'Research Analyst': 'Research Analyst',
    'Research and Development (R&D) Engineer':'R&D Engineer',
    'Research Chemist':'Chemist',
    'Research Psychologist':'Psychologist',
    'Residential Landscape Designer':'Residential Landscape Designer',
    'Residential Interior Designer':'Interior Designer',
    'Risk Analyst':'Risk Analyst',
    'Retail Sales Associate':'Sales Associate',
    'Retirement Planner':'Retirement Planner',
    'Sales Associate': 'Sales Associate',
    'Sales Account Manager':'Sales Manager',
    'Sales Account Executive':'Account Executive',
    'Sales Consultant': 'Sales Consultant',
    'Sales Director': 'Sales Director',
    'Sales Engineer': 'Sales Engineer',
    'Sales Advisor':'Sales Advisor',
    'Sales Manager': 'Sales Manager',
    'Sales Trainer':'Sales Trainer',
    'Sales Representative': 'Sales Representative',
    'Sales Team Leader':'Sales Team Leader',
    'School Principal': 'School Principal',
    'School Social Worker':'Social Worker',
    'School Psychologist':'Psychologist',
    'Secretary': 'Secretary',
    'Senior Researcher':'Senior Researcher',
    'Security Guard': 'Security Guard',
    'Service Quality Assurance Manager':'Quality Manager',
    'Server Developer':'Network Engineer',
    'SEO Specialist': 'SEO Specialist',
    'SEM Specialist': 'SEM Specialist',
    'SEO Copywriter':'SEO Copywriter',
    'SEM Analyst': 'SEM Analyst',
    'SEO Content Strategist':'SEO Content Strategist',
    'Search Engine Marketer':'Search Engine Marketer',
    'SEO Analyst':'SEO Analyst',
    'Security Consultant':'Security Consultant',
    'Security Operations Center (SOC) Analyst':'SOC Analyst',
    'Small Animal Veterinarian':'Veterinarian',
    'Social and Community Service Manager': 'Social and Community Service Manager',
    'Social Media Manager': 'Social Media Manager',
    'Social Media Strategist': 'Social Media Strategist',
    'Social Media Analyst':'Social Media Analyst',
    'Social Worker': 'Social Worker',
    'Social Media Influencer':'Social Media Influencer',
    'Social Science Researcher':'Researcher',
    'Sourcing Analyst':'Sourcing Analyst',
    'Software Engineer': 'Software Developer',
    'Software Engineer-Test': 'Software Tester',
    'Software Tester': 'Software Tester',
    'Software QA Tester':'Software Tester',
    'Solutions Architect': 'Solutions Architect',
    'Solution Architect':'Solutions Architect',
    'Subject Matter Expert':'Subject Matter Expert',
    'Speech Therapist': 'Speech Therapist',
    'Speech Pathologist':'Speech Pathologist',
    'Special Education Teacher':'Teacher',
    'Strategic Manager': 'Strategic Manager',
    'Strategic Account Manager': 'Strategic Manager',
    'Strategic Partnerships Manager':'Strategic Manager',
    'Strategic Sourcing Manager':'Strategic Manager',
    'Store Manager': 'Store Manager',
    'SQL Database Developer':'Database Developer',
    'Supply Chain Manager': 'Supply Manager',
    'Supply Chain Coordinator':'Supply Manager',
    'Supplier Diversity Manager':'Supply Manager',
    'Staff Nurse':'Nurse',
    'Studio Art Teacher':'Teacher',
    'Structural Engineer':'Structural Engineer',
    'Sustainability Consultant':'Consultant',
    'Sustainability Specialist':'Sustainability Specialist',
    'Sustainable Landscape Specialist':'Sustainable Specialist',
    'Sustainable Design Specialist':'Sustainable Design Specialist',
    'Systems Integration Specialist':'Systems Integration Specialist',
    'Systems Administrator':'System Administrator',
    'System Administrator':'System Administrator',
    'Systems Engineer':'Systems Engineer',
    'Surgical Physician Assistant':'Surgical Physician Assistant',
    'Tax Preparer': 'Tax Preparer',
    'Tax Planner':'Tax Preparer',
    'Tax Accountant':'Tax Accountant',
    'Talent Acquisition Manager':'HR Manager',
    'Teacher': 'Teacher',
    'Team Manager': 'Team Manager',
    'Technical Architect': 'Solutions Architect',
    'Technical Manager': 'Technical Manager',
    'Technical SEO Specialist':'Technical SEO Specialist',
    'Technical SEO Analyst':'Technical SEO Analyst',
    'Technical Support': 'Technical Support',
    'Technical Support Specialist': 'Technical Support',
    'Technical Writer': 'Technical Writer',
    'Technical Copywriter': 'Technical Writer',
    'Test Automation Engineer':'Automation Engineer',
    'Territory Sales Manager':'Sales Manager',
    'Translator': 'Translator',
    'Training Manager': 'Training Manager',
    'Training Coordinator':'Training Manager',
    'Trial Attorney':'Lawyer',
    'Transportation Planner':'Transportation Planner',
    'Transportation Engineer':'Transportation Engineer',
    'Treaasury Manager':'Treasury Manager',
    'UI/UX Front-End Developer':'Software Developer',
    'UI Designer': 'UX/UI Professional',
    'UI Developer': 'UX/UI Professional',
    'Urban Planner': 'Urban Planner',
    'UX Designer': 'UX/UI Professional',
    'UX Researcher': 'UX/UI Professional',
    'User Researcher':'UX/UI Professional',
    'UX/UI Designer': 'UX/UI Professional',
    'UI/UX Designer': 'UX/UI Professional',
    'UI/UX Developer':'UX/UI Professional',
    'User Interface Designer':'UX/UI Professional',
    'User Experience Designer':'UX/UI Professional',
    'UX Strategist':'UX/UI Professional',
    'Usability Analyst':'Usability Analyst',
    'Veterinarian': 'Veterinarian',
    'Videographer': 'Videographer',
    'Visual Designer':'Visual Designer',
    'Web Designer': 'Web Designer',
    'Web Graphic Designer': 'Web Graphic Designer',
    'Web Developer': 'Web Developer',
    'Wealth Advisor':'Wealth Advisor',
    'Wealth Management Advisor':'Wealth Advisor',
    'Wedding Consultant': 'Event Planner',
    'Wedding Coordinator':'Event Planner',
    'Wedding Planner': 'Event Planner',
    'Wedding Designer': 'Event Planner',
    'Wireless Network Engineer':'Network Engineer',
    'Writer': 'Writer',
    'Water Resources Engineer':'Water Resources Engineer',
    'Zoologist': 'Zoologist'
}

# %%
# Use the .map() function to apply the mapping to the 'Role' column.
# This creates a new column named 'Standardized_Role'.
df1['Standardized_Role'] = df1['Role'].map(role_mapping)

# To handle roles that were not in the mapping dictionary, you can fill the
# NaN values with the original role name. This ensures no data is lost.
df1['Standardized_Role'] = df1['Standardized_Role'].fillna(df1['Role'])

# Now, 'Standardized_Role' is your clean column, ready for analysis.
# You can drop the original 'Role' column if you want to.
# df = df.drop(columns=['Role'])

# Display the first few rows to confirm the mapping worked.
print(df1[['Role', 'Standardized_Role']].head())

# To see a complete list of your new standardized roles:
# print(df['Standardized_Role'].value_counts())
# Out:
#                         Role          Standardized_Role
# 0       Social Media Manager       Social Media Manager
# 1     Frontend Web Developer         Software Developer
# 2    Quality Control Manager            Quality Manager
# 3  Wireless Network Engineer  Wireless Network Engineer
# 4         Conference Manager         Conference Manager

# %%
 print(df1['Standardized_Role'].value_counts())
# Out:
# Standardized_Role
# Software Developer             8161
# UX/UI Professional             5434
# Network Administrator          4431
# User Experience Designer       3763
# Social Media Manager           3668
#                                ...
# E-commerce Web Designer         842
# Nurse Educator                  842
# Staff Nurse                     840
# Live Chat Support Agent         838
# Paid Advertising Specialist     826
# Name: count, Length: 358, dtype: int64

# %%
df1
# Out:
#           Job_Id  Avg_Experience Qualifications  Min_Salary  Max_Salary  \
# 0       10898400              10         M.Tech       59000       99000
# 1       39845400               7            BCA       56000      116000
# 2       48164000               6            PhD       61000      104000
# 3       68819300               8            PhD       65000       91000
# 4       11705800               6            MBA       64000       87000
# ...          ...             ...            ...         ...         ...
# 421286  89902000               8            MBA       56000       93000
# 421287  59248100               8            PhD       62000      115000
# 421288  82886800               8          M.Com       63000      101000
# 421289  65242300               6            BBA       59000      123000
# 421290  58731600               5          M.Com       61000      109000
#
#              Location                 Country  Work_Type Preference  \
# ...

# %%
df1.shape
# Out:
# (421291, 18)

# %%
df1['Standardized_Role'].duplicated().sum()
# Out:
# 420933

# %%
df1.to_excel("jobs.xlsx", index=False, engine='openpyxl')
